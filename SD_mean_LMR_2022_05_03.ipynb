# %%
import datetime
now = datetime.datetime.now()
print ("Current date and time: ")
print (now.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Current date and time:
# 2022-05-03 16:43:50

# %%
# installing dependencies
#
import pandas as pd
import os
import seaborn as sns
import numpy as np
import datetime
import matplotlib.pyplot as plt
import matplotlib as mpl
import geopandas as gpd
import plotly_express as px

# %%
# read in CSV file for all years mean
#
snow_depth = pd.read_csv ("D:/Users/aster/Desktop/SNOW_DEPTH_2022_04_20/SnowDepth_WhiteDzud_YearlyMean.csv")
df1 = pd.DataFrame(snow_depth)
df1
# Out:
#       DateTime  Arkhangai  BayanUlgii  Bayankhongor    Bulgan  DarkhanUul  \
# 0   12/31/2000   0.038840    0.125558      0.038732  0.056854    0.053582
# 1   12/31/2001   0.043516    0.148666      0.017604  0.055438    0.068587
# 2   12/31/2002   0.027020    0.117529      0.019466  0.044815    0.052776
# 3   12/31/2003   0.026802    0.122053      0.014944  0.052661    0.058532
# 4   12/31/2004   0.017660    0.110923      0.009320  0.048786    0.061555
# 5   12/31/2005   0.018840    0.128049      0.009856  0.041823    0.049049
# 6   12/31/2006   0.012039    0.071817      0.004845  0.030569    0.035068
# 7   12/31/2007   0.010388    0.052249      0.006899  0.028511    0.035163
# 8   12/31/2008   0.009886    0.056121      0.003776  0.020575    0.024890
# 9   12/31/2009   0.089522    0.175027      0.057601  0.106186    0.115896
# 10  12/31/2010   0.046367    0.145740      0.015050  0.086858    0.089714
# 11  12/31/2011   0.022725    0.040730      0.006205  0.049213    0.040929
# ...

# %%
df1.dtypes
# Out:
# DateTime         object
# Arkhangai       float64
# BayanUlgii      float64
# Bayankhongor    float64
# Bulgan          float64
# DarkhanUul      float64
# Dornod          float64
# Dornogovi       float64
# Dundgovi        float64
# GoviAltai       float64
# Govisumber      float64
# Khentii         float64
# Khovd           float64
# Khuvsgul        float64
# Orkhon          float64
# Selenge         float64
# Sukhbaatar      float64
# Tuv             float64
# Ulaanbaatar     float64
# Umnugovi        float64
# Uvs             float64
# Uvurkhangai     float64
# Zavkhan         float64
# dtype: object

# %%
df1['DateTime'] = pd.to_datetime(df1['DateTime'])

# %%
df1.dtypes
# Out:
# DateTime        datetime64[ns]
# Arkhangai              float64
# BayanUlgii             float64
# Bayankhongor           float64
# Bulgan                 float64
# DarkhanUul             float64
# Dornod                 float64
# Dornogovi              float64
# Dundgovi               float64
# GoviAltai              float64
# Govisumber             float64
# Khentii                float64
# Khovd                  float64
# Khuvsgul               float64
# Orkhon                 float64
# Selenge                float64
# Sukhbaatar             float64
# Tuv                    float64
# Ulaanbaatar            float64
# Umnugovi               float64
# Uvs                    float64
# Uvurkhangai            float64
# Zavkhan                float64
# dtype: object

# %%
#Set DateTime as index
#
df1= df1.set_index('DateTime')
df1
# Out:
#             Arkhangai  BayanUlgii  Bayankhongor    Bulgan  DarkhanUul  \
# DateTime
# 2000-12-31   0.038840    0.125558      0.038732  0.056854    0.053582
# 2001-12-31   0.043516    0.148666      0.017604  0.055438    0.068587
# 2002-12-31   0.027020    0.117529      0.019466  0.044815    0.052776
# 2003-12-31   0.026802    0.122053      0.014944  0.052661    0.058532
# 2004-12-31   0.017660    0.110923      0.009320  0.048786    0.061555
# 2005-12-31   0.018840    0.128049      0.009856  0.041823    0.049049
# 2006-12-31   0.012039    0.071817      0.004845  0.030569    0.035068
# 2007-12-31   0.010388    0.052249      0.006899  0.028511    0.035163
# 2008-12-31   0.009886    0.056121      0.003776  0.020575    0.024890
# 2009-12-31   0.089522    0.175027      0.057601  0.106186    0.115896
# 2010-12-31   0.046367    0.145740      0.015050  0.086858    0.089714
# 2011-12-31   0.022725    0.040730      0.006205  0.049213    0.040929
# ...

# %% [markdown]
# ----

# %%
# read in CSV file for LMR
#
air_temp = pd.read_csv ("D:/Users/aster/Desktop/LMR/LMR_Yearly_Provinces.csv")
df2 = pd.DataFrame(air_temp)
df2
# Out:
#     DateTime  Arkhangai  Bayankhongor  BayanUlgii  Bulgan  DarkhanUul  Dornod  \
# 0       2000       0.06          0.09        0.06    0.07        0.03    0.02
# 1       2001       0.24          0.19        0.07    0.13        0.09    0.09
# 2       2002       0.04          0.43        0.13    0.03        0.01    0.02
# 3       2003       0.07          0.02        0.02    0.22        0.08    0.04
# 4       2004       0.01          0.01        0.02    0.01        0.01    0.01
# 5       2005       0.01          0.01        0.07    0.01        0.00    0.01
# 6       2006       0.01          0.01        0.01    0.00        0.00    0.01
# 7       2007       0.01          0.01        0.02    0.01        0.00    0.00
# 8       2008       0.01          0.03        0.04    0.00        0.00    0.01
# 9       2009       0.02          0.07        0.08    0.01        0.01    0.09
# 10      2010       0.30          0.24        0.12    0.09        0.13    0.22
# ...

# %%
df2.dtypes
# Out:
# DateTime          int64
# Arkhangai       float64
# Bayankhongor    float64
# BayanUlgii      float64
# Bulgan          float64
# DarkhanUul      float64
# Dornod          float64
# Dornogovi       float64
# Dundgovi        float64
# GoviAltai       float64
# Govisumber      float64
# Khentii         float64
# Khovd           float64
# Khuvsgul        float64
# Orkhon          float64
# Selenge         float64
# Sukhbaatar      float64
# Tuv             float64
# Ulaanbaatar     float64
# Umnugovi        float64
# Uvs             float64
# Uvurkhangai     float64
# Zavkhan         float64
# dtype: object

# %%
df2['DateTime'] = pd.to_datetime(df2['DateTime'])

# %%
df2.dtypes
# Out:
# DateTime        datetime64[ns]
# Arkhangai              float64
# Bayankhongor           float64
# BayanUlgii             float64
# Bulgan                 float64
# DarkhanUul             float64
# Dornod                 float64
# Dornogovi              float64
# Dundgovi               float64
# GoviAltai              float64
# Govisumber             float64
# Khentii                float64
# Khovd                  float64
# Khuvsgul               float64
# Orkhon                 float64
# Selenge                float64
# Sukhbaatar             float64
# Tuv                    float64
# Ulaanbaatar            float64
# Umnugovi               float64
# Uvs                    float64
# Uvurkhangai            float64
# Zavkhan                float64
# dtype: object

# %%
df2
# Out:
#                         DateTime  Arkhangai  Bayankhongor  BayanUlgii  Bulgan  \
# 0  1970-01-01 00:00:00.000002000       0.06          0.09        0.06    0.07
# 1  1970-01-01 00:00:00.000002001       0.24          0.19        0.07    0.13
# 2  1970-01-01 00:00:00.000002002       0.04          0.43        0.13    0.03
# 3  1970-01-01 00:00:00.000002003       0.07          0.02        0.02    0.22
# 4  1970-01-01 00:00:00.000002004       0.01          0.01        0.02    0.01
# 5  1970-01-01 00:00:00.000002005       0.01          0.01        0.07    0.01
# 6  1970-01-01 00:00:00.000002006       0.01          0.01        0.01    0.00
# 7  1970-01-01 00:00:00.000002007       0.01          0.01        0.02    0.01
# 8  1970-01-01 00:00:00.000002008       0.01          0.03        0.04    0.00
# 9  1970-01-01 00:00:00.000002009       0.02          0.07        0.08    0.01
# 10 1970-01-01 00:00:00.000002010       0.30          0.24        0.12    0.09
# ...

# %%
result = pd.concat([df1, df2])
result
# Out:
#                      Arkhangai  BayanUlgii  Bayankhongor    Bulgan  \
# 2000-12-31 00:00:00   0.038840    0.125558      0.038732  0.056854
# 2001-12-31 00:00:00   0.043516    0.148666      0.017604  0.055438
# 2002-12-31 00:00:00   0.027020    0.117529      0.019466  0.044815
# 2003-12-31 00:00:00   0.026802    0.122053      0.014944  0.052661
# 2004-12-31 00:00:00   0.017660    0.110923      0.009320  0.048786
# 2005-12-31 00:00:00   0.018840    0.128049      0.009856  0.041823
# 2006-12-31 00:00:00   0.012039    0.071817      0.004845  0.030569
# 2007-12-31 00:00:00   0.010388    0.052249      0.006899  0.028511
# 2008-12-31 00:00:00   0.009886    0.056121      0.003776  0.020575
# 2009-12-31 00:00:00   0.089522    0.175027      0.057601  0.106186
# 2010-12-31 00:00:00   0.046367    0.145740      0.015050  0.086858
# 2011-12-31 00:00:00   0.022725    0.040730      0.006205  0.049213
# 2012-12-31 00:00:00   0.041988    0.063953      0.014547  0.084496
# ...

# %%
result = result.iloc[:, :-1]
result
# Out:
#                      Arkhangai  BayanUlgii  Bayankhongor    Bulgan  \
# 2000-12-31 00:00:00   0.038840    0.125558      0.038732  0.056854
# 2001-12-31 00:00:00   0.043516    0.148666      0.017604  0.055438
# 2002-12-31 00:00:00   0.027020    0.117529      0.019466  0.044815
# 2003-12-31 00:00:00   0.026802    0.122053      0.014944  0.052661
# 2004-12-31 00:00:00   0.017660    0.110923      0.009320  0.048786
# 2005-12-31 00:00:00   0.018840    0.128049      0.009856  0.041823
# 2006-12-31 00:00:00   0.012039    0.071817      0.004845  0.030569
# 2007-12-31 00:00:00   0.010388    0.052249      0.006899  0.028511
# 2008-12-31 00:00:00   0.009886    0.056121      0.003776  0.020575
# 2009-12-31 00:00:00   0.089522    0.175027      0.057601  0.106186
# 2010-12-31 00:00:00   0.046367    0.145740      0.015050  0.086858
# 2011-12-31 00:00:00   0.022725    0.040730      0.006205  0.049213
# 2012-12-31 00:00:00   0.041988    0.063953      0.014547  0.084496
# ...

# %%
result = result.drop(result.index[22])
result
# Out:
#                      Arkhangai  BayanUlgii  Bayankhongor    Bulgan  \
# 2000-12-31 00:00:00   0.038840    0.125558      0.038732  0.056854
# 2001-12-31 00:00:00   0.043516    0.148666      0.017604  0.055438
# 2002-12-31 00:00:00   0.027020    0.117529      0.019466  0.044815
# 2003-12-31 00:00:00   0.026802    0.122053      0.014944  0.052661
# 2004-12-31 00:00:00   0.017660    0.110923      0.009320  0.048786
# 2005-12-31 00:00:00   0.018840    0.128049      0.009856  0.041823
# 2006-12-31 00:00:00   0.012039    0.071817      0.004845  0.030569
# 2007-12-31 00:00:00   0.010388    0.052249      0.006899  0.028511
# 2008-12-31 00:00:00   0.009886    0.056121      0.003776  0.020575
# 2009-12-31 00:00:00   0.089522    0.175027      0.057601  0.106186
# 2010-12-31 00:00:00   0.046367    0.145740      0.015050  0.086858
# 2011-12-31 00:00:00   0.022725    0.040730      0.006205  0.049213
# 2012-12-31 00:00:00   0.041988    0.063953      0.014547  0.084496
# ...

# %% [markdown]
# ----

# %%
#Scatter Plots per Province all years

# %%
Zavkhan=result['Zavkhan']

# %%
Zavkhan_sd= Zavkhan.iloc[:22]
Zavkhan_sd.reset_index(drop=True, inplace=True)
Zavkhan_sd
# Out:
# 0     0.014094
# 1     0.011100
# 2     0.014779
# 3     0.015558
# 4     0.010408
# 5     0.009043
# 6     0.006720
# 7     0.006605
# 8     0.005036
# 9     0.063677
# 10    0.023503
# 11    0.005863
# 12    0.018339
# 13    0.006265
# 14    0.004042
# 15    0.011632
# 16    0.015360
# 17    0.014961
# 18    0.010471
# 19    0.007028
# 20    0.006648
# 21    0.026729
# Name: Uvurkhangai, dtype: float64

# %%
Zavkhan_lm= Zavkhan.iloc[22:]
Zavkhan_lm.reset_index(drop=True, inplace=True)
Zavkhan_lm
# Out:
# 0     0.14
# 1     0.12
# 2     0.03
# 3     0.00
# 4     0.02
# 5     0.01
# 6     0.00
# 7     0.04
# 8     0.03
# 9     0.46
# 10    0.01
# 11    0.00
# 12    0.01
# 13    0.00
# 14    0.02
# 15    0.01
# 16    0.01
# 17    0.06
# 18    0.02
# 19    0.04
# 20    0.00
# Name: Uvurkhangai, dtype: float64

# %%
#new dataframe
result1 = pd.concat([Zavkhan_sd, Zavkhan_lm], axis=1)
result1
# Out:
#     Uvurkhangai  Uvurkhangai
# 0      0.014094         0.14
# 1      0.011100         0.12
# 2      0.014779         0.03
# 3      0.015558         0.00
# 4      0.010408         0.02
# 5      0.009043         0.01
# 6      0.006720         0.00
# 7      0.006605         0.04
# 8      0.005036         0.03
# 9      0.063677         0.46
# 10     0.023503         0.01
# 11     0.005863         0.00
# 12     0.018339         0.01
# 13     0.006265         0.00
# 14     0.004042         0.02
# 15     0.011632         0.01
# 16     0.015360         0.01
# 17     0.014961         0.06
# 18     0.010471         0.02
# 19     0.007028         0.04
# 20     0.006648         0.00
# 21     0.026729          NaN

# %%
#Save as csv
result1.to_csv('Zavkhan_sd_lm_avg.csv')

# %%
result1.columns = ['Snow Depth', 'LMR']
result1
# Out:
#     Snow Depth   LMR
# 0     0.014094  0.14
# 1     0.011100  0.12
# 2     0.014779  0.03
# 3     0.015558  0.00
# 4     0.010408  0.02
# 5     0.009043  0.01
# 6     0.006720  0.00
# 7     0.006605  0.04
# 8     0.005036  0.03
# 9     0.063677  0.46
# 10    0.023503  0.01
# 11    0.005863  0.00
# 12    0.018339  0.01
# 13    0.006265  0.00
# 14    0.004042  0.02
# 15    0.011632  0.01
# 16    0.015360  0.01
# 17    0.014961  0.06
# 18    0.010471  0.02
# 19    0.007028  0.04
# 20    0.006648  0.00
# 21    0.026729   NaN

# %%
#Ordinary Least Squares Regression Trendline
fig = px.scatter(result1, x='Snow Depth', y='LMR', trendline='ols', title='Zavkhan: R^2='+str(a))
fig.show()
# Out:
# <div>                            <div id="393cc63a-b1ad-4861-b164-ab56a7a0f87a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("393cc63a-b1ad-4861-b164-ab56a7a0f87a")) {                    Plotly.newPlot(                        "393cc63a-b1ad-4861-b164-ab56a7a0f87a",                        [{"hovertemplate":"Snow Depth=%{x}<br>LMR=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[0.014093887,0.011100205,0.014779172,0.015558234,0.010408009,0.009042769,0.006720264,0.006604644,0.005036076,0.063677021,0.023503087,0.005862949,0.018338921,0.006264832,0.004041939,0.011632434,0.015359666,0.01496101,0.010470885,0.007027833,0.006647566,0.026728587],"xaxis":
# ...

# %%
a = px.get_trendline_results(fig).px_fit_results.iloc[0].rsquared
a
# Out:
# 0.755337244007814

# %% [markdown]
# #### Pearson’s Correlation
# The Pearson correlation coefficient (named for Karl Pearson) can be used to summarize the strength of the linear relationship between two data samples.
#
# The Pearson’s correlation coefficient is calculated as the covariance of the two variables divided by the product of the standard deviation of each data sample. It is the normalization of the covariance between the two variables to give an interpretable score.

# %%
result1.corr(method ='pearson')
# Out:
#             Snow Depth       LMR
# Snow Depth    1.000000  0.869101
# LMR           0.869101  1.000000
